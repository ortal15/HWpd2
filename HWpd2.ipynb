# %%
import numpy as np
from IPython.display import display
import pandas as pd

# %%
df = pd.read_csv("hw_work.csv")

# %%
#1
print('מידע על הנתונים')
df.info()
print()
print('עמודות עם ערכים חסרים')
print(df.isnull().sum())
print()
print('כמות הזיכרון')
print(df.memory_usage().sum())
# Out:
# מידע על הנתונים
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3323 non-null   float64
#  7   Total day calls         3323 non-null   float64
#  8   Total day charge        3315 non-null   float64
#  9   Total eve minutes       3324 non-null   float64
#  10  Total eve calls         3325 non-null   float64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3332 non-null   float64
# ...

# %%
#2
print('עמודות הטבלה באמצעות describe:')
print(df.describe())
print()
print('הערך הכי גבוה עבור עמודת עמודת length Account:')
df['Account length'].max()
# Out:
# עמודות הטבלה באמצעות describe:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# ...

# %%
#3
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#4
print('הדפס את השורה באינדקס ,14 רמז iloc:')
df.iloc[14]
# Out:
# הדפס את השורה באינדקס ,14 רמז iloc:
# State                        IA
# Account length               62
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         307.2
# Total eve calls            76.0
# Total eve charge          26.11
# Total night minutes       203.0
# Total night calls          99.0
# Total night charge         9.14
# Total intl minutes         13.1
# Total intl calls              6
# Total intl charge          3.54
# Customer service calls      4.0
# Churn                     False
# Name: 14, dtype: object

# %%
print('הדפס את השורות באינדקס 14 עד הסוף, רמז iloc')
df.iloc[14:]
# Out:
# הדפס את השורות באינדקס 14 עד הסוף, רמז iloc
#      State  Account length  Area code International plan Voice mail plan  \
# 14      IA              62        415                 No              No
# 15      NY             161        415                 No              No
# 16      ID              85        408                 No             Yes
# 17      VT              93        510                 No              No
# 18      VA              76        510                 No             Yes
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
# ...

# %%
#5
df.drop('Area code', axis=1)
# Out:
#      State  Account length International plan Voice mail plan  \
# 0       KS             128                 No             Yes
# 1       OH             107                 No             Yes
# 2       NJ             137                 No              No
# 3       OH              84                Yes              No
# 4       OK              75                Yes              No
# ...    ...             ...                ...             ...
# 3328    AZ             192                 No             Yes
# 3329    WV              68                 No              No
# 3330    RI              28                 No              No
# 3331    CT             184                Yes              No
# 3332    TN              74                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# ...

# %%
#6
df.drop(3328, axis=0)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#7
df['total_min'] = df['Total intl minutes'] + df['Total night minutes']

# %%
#8
new_df = pd.concat([df.iloc[[0]], df.iloc[[-1]]], ignore_index=False)
new_df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  ...  Total eve charge  \
# 0                45.07              197.4  ...             16.78
# 3332             39.85              265.9  ...             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7               91.0               11.01
# 3332                241.4               77.0               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3                2.7
# ...
